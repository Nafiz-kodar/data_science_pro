# %%
import pandas as pd

# %%
df = pd.read_csv('mental_health_social_media_dataset.csv')
df.head(50)
# Out:
#     person_name         age   date         gender   platform   \
# 0   Reyansh Ghosh        35   1/1/2024     Male     Instagram
# 1   Neha Patel           24   1/12/2024    Female   Instagram
# 2   Ananya Naidu         26   1/6/2024     Male     Snapchat
# 3   Neha Das             66   1/17/2024    Female   Snapchat
# 4   Reyansh Banerjee     31   1/28/2024    Male     Snapchat
# 5   Myra Kale            25   2/8/2024     Female   Snapchat
# 6   Ananya Kulkarni      29   2/19/2024    Other    Snapchat
# 7   Meera Das            28   1/11/2024    Female   Facebook
# 8   Vihaan Naidu         31   1/22/2024    Male     Facebook
# 9   Meera Patil          26   2/2/2024     Female   Facebook
# 10  Suhani Das           39   1/16/2024    Male     WhatsApp
# 11  Vivaan Shetty        28   1/27/2024    Male     WhatsApp
# 12  Diya Saxena          33   2/7/2024     Female   WhatsApp
# 13  Sai Verma            30   1/21/2024    Female   TikTok
# ...
